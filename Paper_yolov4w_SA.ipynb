# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/YOLO/yolov4w
# Out:
# /content/drive/MyDrive/YOLO/yolov4w

# %%
# !git clone https://github.com/WongKinYiu/PyTorch_YOLOv4.git
# Out:
# Cloning into 'PyTorch_YOLOv4'...
# remote: Enumerating objects: 651, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 651 (delta 0), reused 1 (delta 0), pack-reused 648
# Receiving objects: 100% (651/651), 1.28 MiB | 7.87 MiB/s, done.
# Resolving deltas: 100% (351/351), done.

# %%
# %cd /content/drive/MyDrive/YOLO/yolov4w/PyTorch_YOLOv4
# !pip install -r requirements.txt
# This restarts the runtime--ignore any error messages
import os
os.kill(os.getpid(), 9)
# Out:
# /content/drive/MyDrive/YOLO/yolov4w/PyTorch_YOLOv4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 50.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
# ERROR: Could not find a version that satisfies the requirement torch==1.6 (from versions: 1.7.1, 1.8.0, 1.8.1, 1.9.0, 1.9.1, 1.10.0, 1.10.1, 1.10.2, 1.11.0, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 2.0.0)
# ERROR: No matching distribution found for torch==1.6

# %%
# %cd /content/drive/MyDrive/YOLO/yolov4w/PyTorch_YOLOv4
#!python train.py --data roboflowDataset.yaml --cfg cfg/yolov4-tiny.cfg --weights cfg/yolov4-tiny.conv.29 --epochs  4000
# Out:
# /content/drive/MyDrive/YOLO/yolov4w/PyTorch_YOLOv4

# %%
# !python train.py --data roboflowDataset.yaml --cfg cfg/yolov4-tiny.cfg --epochs  4000
# Out:
# Streaming output truncated to the last 5000 lines.
#                  all          23         357       0.789       0.947       0.909       0.456
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#  1874/3999     3.12G   0.03026    0.2205         0    0.2507       129       640: 100% 15/15 [00:11<00:00,  1.35it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  2.12it/s]
#                  all          23         357       0.788       0.947        0.91       0.456
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#  1875/3999     3.12G   0.03083    0.2113         0    0.2421       170       640: 100% 15/15 [00:08<00:00,  1.86it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.42it/s]
# ...

# %%
ls
# Out:
# cfg/            detect.py  __pycache__/      runs/     utils/
# data/           images/    README.md         test.py   weights/
# data-original/  models/    requirements.txt  train.py

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs/train/exp

# %%
#23 images last
# !python test.py --save-conf --save-txt --img 608 --conf 0.001 --batch 16 --device 0 --data roboflowDataset.yaml --cfg cfg/yolov4-tiny.cfg --weights runs/train/exp/weights/last.pt --iou 0.5
# Out:
# /content/drive/MyDrive/yolov4w/PyTorch_YOLOv4/utils/plots.py:23: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "test.py", line 13, in <module>
#     from utils.datasets import create_dataloader
#   File "/content/drive/MyDrive/yolov4w/PyTorch_YOLOv4/utils/datasets.py", line 26, in <module>
#     from utils.general import xyxy2xywh, xywh2xyxy
#   File "/content/drive/MyDrive/yolov4w/PyTorch_YOLOv4/utils/general.py", line 21, in <module>
#     from utils.metrics import fitness, fitness_p, fitness_r, fitness_ap50, fitness_ap, fitness_f
#   File "/content/drive/MyDrive/yolov4w/PyTorch_YOLOv4/utils/metrics.py", line 3, in <module>
#     import matplotlib.pyplot as plt
# ...

# %%
#23 images best
# !python test.py --save-conf --save-txt --img 608 --conf 0.001 --batch 16 --device 0 --data roboflowDataset.yaml --cfg cfg/yolov4-tiny.cfg --weights runs/train/exp/weights/best.pt --iou 0.5
# Out:
# /content/drive/MyDrive/yolov4w/PyTorch_YOLOv4/utils/plots.py:23: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "test.py", line 13, in <module>
#     from utils.datasets import create_dataloader
#   File "/content/drive/MyDrive/yolov4w/PyTorch_YOLOv4/utils/datasets.py", line 26, in <module>
#     from utils.general import xyxy2xywh, xywh2xyxy
#   File "/content/drive/MyDrive/yolov4w/PyTorch_YOLOv4/utils/general.py", line 21, in <module>
#     from utils.metrics import fitness, fitness_p, fitness_r, fitness_ap50, fitness_ap, fitness_f
#   File "/content/drive/MyDrive/yolov4w/PyTorch_YOLOv4/utils/metrics.py", line 3, in <module>
#     import matplotlib.pyplot as plt
# ...

# %%
#11 images last
# !python test.py --save-conf --save-txt --img 608 --conf 0.001 --batch 16 --device 0 --data roboflowDatasetVal.yaml --cfg cfg/yolov4-tiny.cfg --weights runs/train/exp/weights/last.pt --iou 0.5
# Out:
# /content/drive/MyDrive/yolov4w/PyTorch_YOLOv4/utils/plots.py:23: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "test.py", line 13, in <module>
#     from utils.datasets import create_dataloader
#   File "/content/drive/MyDrive/yolov4w/PyTorch_YOLOv4/utils/datasets.py", line 26, in <module>
#     from utils.general import xyxy2xywh, xywh2xyxy
#   File "/content/drive/MyDrive/yolov4w/PyTorch_YOLOv4/utils/general.py", line 21, in <module>
#     from utils.metrics import fitness, fitness_p, fitness_r, fitness_ap50, fitness_ap, fitness_f
#   File "/content/drive/MyDrive/yolov4w/PyTorch_YOLOv4/utils/metrics.py", line 3, in <module>
#     import matplotlib.pyplot as plt
# ...

# %%
#11 images best
# !python test.py --save-conf --save-txt --img 608 --conf 0.001 --batch 16 --device 0 --data roboflowDatasetVal.yaml --cfg cfg/yolov4-tiny.cfg --weights runs/train/exp/weights/best.pt --iou 0.5
# Out:
# /content/drive/MyDrive/yolov4w/PyTorch_YOLOv4/utils/plots.py:23: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "test.py", line 13, in <module>
#     from utils.datasets import create_dataloader
#   File "/content/drive/MyDrive/yolov4w/PyTorch_YOLOv4/utils/datasets.py", line 26, in <module>
#     from utils.general import xyxy2xywh, xywh2xyxy
#   File "/content/drive/MyDrive/yolov4w/PyTorch_YOLOv4/utils/general.py", line 21, in <module>
#     from utils.metrics import fitness, fitness_p, fitness_r, fitness_ap50, fitness_ap, fitness_f
#   File "/content/drive/MyDrive/yolov4w/PyTorch_YOLOv4/utils/metrics.py", line 3, in <module>
#     import matplotlib.pyplot as plt
# ...

# %%
ls
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# ls: cannot open directory '.': Transport endpoint is not connected

# %%
#!python test.py --weights runs/train/exp/weights/best.pt --data dataset.yaml --img 640 --iou 0.65
# !python test.py --img 640 --conf 0.001 --batch 16 --device 0 --data roboflowDataset.yaml --cfg cfg/yolov4-tiny.cfg --weights runs/train/exp2/weights/best.pt --iou 0.5
# Out:
# /content/drive/MyDrive/yolov4w/PyTorch_YOLOv4/utils/plots.py:23: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "test.py", line 13, in <module>
#     from utils.datasets import create_dataloader
#   File "/content/drive/MyDrive/yolov4w/PyTorch_YOLOv4/utils/datasets.py", line 26, in <module>
#     from utils.general import xyxy2xywh, xywh2xyxy
#   File "/content/drive/MyDrive/yolov4w/PyTorch_YOLOv4/utils/general.py", line 21, in <module>
#     from utils.metrics import fitness, fitness_p, fitness_r, fitness_ap50, fitness_ap, fitness_f
#   File "/content/drive/MyDrive/yolov4w/PyTorch_YOLOv4/utils/metrics.py", line 3, in <module>
#     import matplotlib.pyplot as plt
# ...

# %%
# !python test.py --img 640 --conf 0.001 --batch 16 --device 0 --data roboflowDataset.yaml --cfg cfg/yolov4-tiny.cfg --weights runs/train/exp2/weights/last.pt --iou 0.5
# Out:
# /content/drive/MyDrive/yolov4w/PyTorch_YOLOv4/utils/plots.py:23: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "test.py", line 13, in <module>
#     from utils.datasets import create_dataloader
#   File "/content/drive/MyDrive/yolov4w/PyTorch_YOLOv4/utils/datasets.py", line 26, in <module>
#     from utils.general import xyxy2xywh, xywh2xyxy
#   File "/content/drive/MyDrive/yolov4w/PyTorch_YOLOv4/utils/general.py", line 21, in <module>
#     from utils.metrics import fitness, fitness_p, fitness_r, fitness_ap50, fitness_ap, fitness_f
#   File "/content/drive/MyDrive/yolov4w/PyTorch_YOLOv4/utils/metrics.py", line 3, in <module>
#     import matplotlib.pyplot as plt
# ...

# %%
# %tensorboard --logdir runs/test/exp12

# %%
#choose random test image
import os
test_images = [f for f in os.listdir('images') if f.endswith('.png')]
import random
img_path = "images/" + random.choice(test_images);

# %%
# !python detect.py --weights runs/train/exp/weights/last.pt --cfg cfg/yolov4-tiny.cfg --img 640  --source /content/drive/MyDrive/yolov4w/PyTorch_YOLOv4/images/100kX_300kV_0537_1_1.png

# %%
from IPython.display import Image
Image('/content/drive/MyDrive/yolov4w/PyTorch_YOLOv4/inference/output/100kX_300kV_0537_1_1.png')

# %%
import torch
print(torch.cuda.is_available())
print(torch.__version__)

# %%
# !pip install GPUtil

import torch
from GPUtil import showUtilization as gpu_usage
from numba import cuda

def free_gpu_cache():
    print("Initial GPU Usage")
    gpu_usage()                             

    torch.cuda.empty_cache()

    cuda.select_device(0)
    cuda.close()
    cuda.select_device(0)

    print("GPU Usage after emptying the cache")
    gpu_usage()

free_gpu_cache()
